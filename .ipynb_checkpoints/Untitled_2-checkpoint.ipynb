# %%
import pandas as pd
import seaborn as sns

# %%
DATA = pd.read_clipboard()
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CVE_UNICA_PDV             479 non-null    object
#  1   PDV                       479 non-null    object
#  2   Sueldos y comisiones ($)  479 non-null    int64
#  3   Renta ($)                 479 non-null    int64
#  4   SyC Promedio              479 non-null    int64
#  5   Renta Promedio            479 non-null    int64
#  6   Sueldos y comisiones (%)  479 non-null    float64
#  7   Renta (%)                 479 non-null    float64
#  8   DELTA                     479 non-null    float64
#  9   SC NEGATIVO               479 non-null    int64
#  10  SC NEGATIVO ACUMULADO     479 non-null    int64
#  11  CLUSTER                   479 non-null    object
#  12  ESTATUS                   479 non-null    int64
#  13  ORIGEN                    479 non-null    object
#  14  REGION                    479 non-null    object
#  15  HC                        479 non-null    int64
#  16  ARPU                      479 non-null    int64
#  17  BREAK EVEN                479 non-null    int64
#  18  MAP                       479 non-null    int64
#  19  CLASIFICACION             479 non-null    object
# dtypes: float64(3), int64(11), object(6)
# memory usage: 75.0+ KB

# %%
ACTIVOS = DATA.query("ESTATUS == 1 and MAP != 0")

# %%
ACTIVOS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 456 entries, 0 to 470
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CVE_UNICA_PDV             456 non-null    object
#  1   PDV                       456 non-null    object
#  2   Sueldos y comisiones ($)  456 non-null    int64
#  3   Renta ($)                 456 non-null    int64
#  4   SyC Promedio              456 non-null    int64
#  5   Renta Promedio            456 non-null    int64
#  6   Sueldos y comisiones (%)  456 non-null    float64
#  7   Renta (%)                 456 non-null    float64
#  8   DELTA                     456 non-null    float64
#  9   SC NEGATIVO               456 non-null    int64
#  10  SC NEGATIVO ACUMULADO     456 non-null    int64
#  11  CLUSTER                   456 non-null    object
#  12  ESTATUS                   456 non-null    int64
#  13  ORIGEN                    456 non-null    object
#  14  REGION                    456 non-null    object
#  15  HC                        456 non-null    int64
#  16  ARPU                      456 non-null    int64
#  17  BREAK EVEN                456 non-null    int64
#  18  MAP                       456 non-null    int64
#  19  CLASIFICACION             456 non-null    object
# dtypes: float64(3), int64(11), object(6)
# memory usage: 74.8+ KB

# %%
ACTIVOS["Sueldos y comisiones (%)"].max()
# Out:
# 1.19

# %%
# fig = px.scatter(ACTIVOS, x="DELTA", y="Sueldos y comisiones (%)",
#                  color="CLUSTER", size="Renta Promedio",
#                  hover_data=["PDV"])

# # Crear la aplicación Dash
# # Crear la aplicación Dash
# app = dash.Dash(__name__)

# # Definir los filtros interactivos
# sc_negativo_options = [{'label': str(x), 'value': x} for x in sorted(ACTIVOS['SC NEGATIVO ACUMULADO'].unique())]
# origen_options = [{'label': o, 'value': o} for o in ACTIVOS['ORIGEN'].unique()]
# region_options = [{'label': r, 'value': r} for r in ACTIVOS['REGION'].unique()]

# # Definir el diseño de la aplicación
# app.layout = html.Div([
#     html.H1('Rentabilidad de las tiendas YTD 2023', style={'text-align': 'center'}),
#     html.Div([
#         html.Label('Filtro SC Negativo Acumulado:'),
#         dcc.Dropdown(
#             id='filtro-sc-negativo',
#             options=sc_negativo_options,
#             value=None,
#             placeholder='Seleccione un valor'
#         )
#     ], style={'width': '30%', 'margin-bottom': '10px'}),
#     html.Div([
#         html.Label('Filtro Región:', style={'text-align': 'left'}),
#         html.Div([
#             dcc.Checklist(
#                 id='filtro-region',
#                 options=region_options,
#                 value=[],
#                 labelStyle={'display': 'inline-block', 'margin-right': '10px'}
#             )
#         ], style={'display': 'inline-block', 'width': '70%', 'text-align': 'center'})
#     ], style={'width': '100%', 'margin-bottom': '10px'}),
#     html.Div([
#         html.Label('Filtro Origen:'),
#         dcc.Checklist(
#             id='filtro-origen',
#             options=origen_options,
#             value=[],
#             labelStyle={'display': 'block'}
#         )
#     ], style={'width': '30%', 'margin-bottom': '10px'}),
#     dcc.Graph(id='scatter-plot', figure=fig)
# ])

# # Definir las funciones de actualización de la gráfica
# @app.callback(
#     dash.dependencies.Output('scatter-plot', 'figure'),
#     [dash.dependencies.Input('filtro-sc-negativo', 'value'),
#      dash.dependencies.Input('filtro-origen', 'value'),
#      dash.dependencies.Input('filtro-region', 'value')]
# )
# def update_scatter_plot(sc_negativo, origen, region):
#     filtered_df = ACTIVOS.copy()
#     if sc_negativo is not None:
#         filtered_df = filtered_df[filtered_df['SC NEGATIVO ACUMULADO'] == sc_negativo]
#     if origen:
#         filtered_df = filtered_df[filtered_df['ORIGEN'].isin(origen)]
#     if region:
#         filtered_df = filtered_df[filtered_df['REGION'].isin(region)]
#     updated_fig = px.scatter(filtered_df, x="DELTA", y="Sueldos y comisiones (%)",
#                              facet_col = "ORIGEN",
#                              # facet_col_wrap=2,
#                              color="CLUSTER", size="Renta Promedio",
#                              hover_name = "PDV",
#                              hover_data = {
#                                  "ORIGEN" : True,
#                                  "CLASIFICACION" : True,
#                                  "HC" : ":,.0f",
#                                  'ARPU':':$.0f',
#                                  "MAP" : ":,.0f",
#                                  "BREAK EVEN" : ":,.0f",
#                                  "Renta Promedio" : ":$,.0f"
#                              })
#                              # hover_data=["ORIGEN","CLASIFICACION","HC","ARPU","MAP","BREAK EVEN"])
#     return updated_fig

# # Ejecutar la aplicación Dash
# if __name__ == '__main__':
#     app.run_server(debug=True)

# %%
# # Crear la aplicación Dash
# app = dash.Dash(__name__)

# # Definir el diseño de la aplicación
# app.layout = html.Div([
#     html.H1('Rentabilidad de las tiendas YTD 2023', style={'text-align': 'center'}),
#     html.Div([
#         html.Label('Filtro SC Negativo Acumulado:'),
#         dcc.Dropdown(
#             id='filtro-sc-negativo',
#             options=[{'label': str(x), 'value': x} for x in sorted(ACTIVOS['SC NEGATIVO ACUMULADO'].unique())],
#             value=None,
#             placeholder='Seleccione un valor'
#         )
#     ], style={'width': '30%', 'margin-bottom': '10px'}),
#     html.Div([
#         html.Label('Filtro Región:', style={'text-align': 'left'}),
#         html.Div([
#             dcc.Checklist(
#                 id='filtro-region',
#                 options=[{'label': r, 'value': r} for r in ACTIVOS['REGION'].unique()],
#                 value=[],
#                 labelStyle={'display': 'inline-block', 'margin-right': '10px'}
#             )
#         ], style={'display': 'inline-block', 'width': '70%', 'text-align': 'center'})
#     ], style={'width': '100%', 'margin-bottom': '10px'}),
#     html.Div([
#         html.Label('Filtro Origen:'),
#         dcc.Checklist(
#             id='filtro-origen',
#             options=[{'label': o, 'value': o} for o in ACTIVOS['ORIGEN'].unique()],
#             value=[],
#             labelStyle={'display': 'block'}
#         )
#     ], style={'width': '30%', 'margin-bottom': '10px'}),
#     html.Button('Mostrar Por Origen/Total', id='toggle-facet-col', n_clicks=0, style={'margin-bottom': '10px'}),
#     dcc.Graph(id='scatter-plot', figure=fig)
# ])

# # Definir las funciones de actualización de la gráfica
# @app.callback(
#     dash.dependencies.Output('scatter-plot', 'figure'),
#     [dash.dependencies.Input('filtro-sc-negativo', 'value'),
#      dash.dependencies.Input('filtro-origen', 'value'),
#      dash.dependencies.Input('filtro-region', 'value'),
#      dash.dependencies.Input('toggle-facet-col', 'n_clicks')]
# )
# def update_scatter_plot(sc_negativo, origen, region, n_clicks):
#     filtered_df = ACTIVOS.copy()
#     if sc_negativo is not None:
#         filtered_df = filtered_df[filtered_df['SC NEGATIVO ACUMULADO'] == sc_negativo]
#     if origen:
#         filtered_df = filtered_df[filtered_df['ORIGEN'].isin(origen)]
#     if region:
#         filtered_df = filtered_df[filtered_df['REGION'].isin(region)]
    
#     facet_col = "ORIGEN" if n_clicks % 2 == 1 else None
    
#     updated_fig = px.scatter(filtered_df, x="DELTA", y="Sueldos y comisiones (%)",
#                              facet_col=facet_col,
#                              color="CLUSTER", size="Renta Promedio",
#                              hover_name="PDV",
#                              hover_data={
#                                  "ORIGEN": True,
#                                  "CLASIFICACION": True,
#                                  "HC": ":,.0f",
#                                  'ARPU': ':$.0f',
#                                  "MAP": ":,.0f",
#                                  "BREAK EVEN": ":,.0f",
#                                  "Renta Promedio": ":$,.0f"
#                              })
#     return updated_fig

# # Ejecutar la aplicación Dash
# if __name__ == '__main__':
#     app.run_server(debug=True)

# %%
import plotly.io as pio

fig = px.scatter(ACTIVOS, x="DELTA", y="Sueldos y comisiones (%)",
                 color="CLUSTER", size="Renta Promedio",
                 hover_data=["PDV"])


app = dash.Dash(__name__)

# Definir el diseño de la aplicación
app.layout = html.Div([
    html.H1('Rentabilidad de las tiendas YTD 2023', style={'text-align': 'center'}),
    html.Div([
        html.Label('Filtro SC Negativo Acumulado:'),
        dcc.Dropdown(
            id='filtro-sc-negativo',
            options=[{'label': str(x), 'value': x} for x in sorted(ACTIVOS['SC NEGATIVO ACUMULADO'].unique())],
            value=None,
            placeholder='Seleccione un valor'
        )
    ], style={'width': '30%', 'margin-bottom': '10px'}),
    html.Div([
        html.Label('Región:', style={'text-align': 'left'}),
        html.Div([
            dcc.Checklist(
                id='filtro-region',
                options=[{'label': r, 'value': r} for r in ACTIVOS['REGION'].unique()],
                value=[],
                labelStyle={'display': 'inline-block', 'margin-right': '10px'}
            )
        ], style={'display': 'inline-block', 'width': '70%', 'text-align': 'center'})
    ], style={'width': '100%', 'margin-bottom': '10px'}),
    html.Button('Mostrar Por Origen/Total', id='toggle-facet-col', n_clicks=0, style={'margin-bottom': '10px'}),
    dcc.Graph(id='scatter-plot', figure=fig)
])

# Definir las funciones de actualización de la gráfica
@app.callback(
    dash.dependencies.Output('scatter-plot', 'figure'),
    [dash.dependencies.Input('filtro-sc-negativo', 'value'),
     dash.dependencies.Input('filtro-region', 'value'),
     dash.dependencies.Input('toggle-facet-col', 'n_clicks')]
)
def update_scatter_plot(sc_negativo, region, n_clicks):
    filtered_df = ACTIVOS.copy()
    if sc_negativo is not None:
        filtered_df = filtered_df[filtered_df['SC NEGATIVO ACUMULADO'] == sc_negativo]
    if region:
        filtered_df = filtered_df[filtered_df['REGION'].isin(region)]
    
    facet_col = "ORIGEN" if n_clicks % 2 == 1 else None
    
    updated_fig = px.scatter(filtered_df, x="DELTA", y="Sueldos y comisiones (%)",
                             facet_col=facet_col,
                             color="CLUSTER", size="Renta Promedio",
                             hover_name="PDV",
                             hover_data={
                                 "ORIGEN": True,
                                 "CLASIFICACION": True,
                                 "HC": ":,.0f",
                                 'ARPU': ':$.0f',
                                 "MAP": ":,.0f",
                                 "BREAK EVEN": ":,.0f",
                                 "Renta Promedio": ":$,.0f"
                             })
    return updated_fig

# Ejecutar la aplicación Dash
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
